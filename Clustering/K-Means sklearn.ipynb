# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
x,y=make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
kmeans=KMeans(n_clusters=5)

# %%
kmeans.fit(x,y)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[-7.6726196  -5.69211059]
#  [ 0.88641907  4.19441853]
#  [ 7.8649674   7.97988109]
#  [-9.0671623  -0.96740759]
#  [-3.97953526  0.19458336]]

# %%
plt.scatter(x[:,0],x[:,1])
centers=kmeans.cluster_centers_
plt.scatter(centers[:,0],centers[:,1],marker="*",color="black")
plt.show()

# %%
pred=kmeans.labels_

# %%
print(pred)
# Out:
# [0 2 4 0 0 4 3 0 2 0 2 4 2 0 4 0 2 0 0 2 1 1 0 4 0 1 3 3 4 3 0 3 1 1 0 1 2
#  2 0 1 1 1 3 3 4 2 2 3 3 3 2 0 3 0 0 1 0 0 2 4 2 4 4 0 3 2 4 4 1 4 1 0 1 0
#  1 4 0 3 1 1 4 1 4 3 2 3 4 2 3 4 3 1 0 1 1 2 0 4 4 1 2 1 4 4 2 2 2 4 4 0 2
#  3 0 2 4 1 2 3 1 4 2 4 3 0 1 3 3 3 0 0 4 4 0 2 2 3 4 3 4 0 0 1 4 2 3 0 2 2
#  0 4 0 0 4 4 2 1 1 3 4 0 1 2 3 1 2 1 2 1 1 1 3 0 1 2 1 3 0 4 2 3 2 0 2 1 3
#  3 1 0 4 2 1 4 3 0 3 1 4 3 0 0 0 1 1 2 0 3 3 0 2 0 0 0 1 2 4 2 0 0 2 3 4 3
#  3 1 0 4 0 4 3 1 4 4 0 1 0 1 4 2 4 1 1 2 0 0 4 4 1 2 1 0 3 2 3 0 3 3 3 3 2
#  1 2 0 1 2 3 4 2 2 2 3 0 0 4 1 1 2 4 4 0 4 3 4 2 2 3 3 1 3 3 2 1 0 4 1 4 3
#  4 4 2 0 1 2 1 1 0 3 1 4 1 3 0 0 4 2 1 3 2 1 4 3 2 3 0 1 3 4 4 1 1 1 0 3 1
#  0 2 4 4 3 2 2 4 4 3 1 1 1 0 3 2 3 0 1 2 2 4 1 1 3 1 3 4 4 4 3 1 0 1 4 3 3
#  2 0 2 3 0 3 4 2 1 2 4 0 0 2 2 1 2 1 3 4 2 3 0 0 2 4 1 3 0 0 0 3 2 1 2 2 2
#  3 1 4 2 4 4 3 4 0 4 0 2 1 1 0 2 3 0 1 4 2 3 4 3 3 2 3 4 3 2 3 4 3 0 1 1 3
#  1 2 1 1 3 0 0 4 3 1 4 3 4 2 4 2 0 1 4 0 4 0 0 1 0 1 3 2 2 4 0 0 3 3 2 3 3
#  2 3 2 2 2 3 1 3 4 2 4 4 3 4 3 1 1 3 2]
